# %% [markdown]
# <a href="https://colab.research.google.com/github/prakash2389/python_utilities/blob/main/pdf%20table%20extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install camelot-py
import camelot
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.0/41.0 kB 1.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 17.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 271.1/271.1 kB 27.6 MB/s eta 0:00:00
# ...

# %%
import tabula

# %%
# !pip install tabula-py
import tabula
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 121.5 MB/s eta 0:00:00
# ...

# %%
# Provide the path to the PDF file
pdf_path = '/content/ORMC UHC Commercial PA eff 1.1.18.1.pdf'

# Extract tables using tabula
tables = tabula.read_pdf(pdf_path, pages='all', multiple_tables=True)

# Iterate through extracted tables
for table_num, table in enumerate(tables, start=1):
    if table_num==7:
      print(f"Table {table_num}:")
      print(table.columns)
      print(table)
      print("\n")
# Out:
# WARNING:tabula.io:Got stderr: Aug 21, 2023 6:53:48 AM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'LiberationSerif' for 'TimesNewRomanPSMT'
# Aug 21, 2023 6:53:48 AM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'LiberationSerif-Bold' for 'TimesNewRomanPS-BoldMT'
# Aug 21, 2023 6:53:49 AM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'LiberationSerif' for 'TimesNewRomanPSMT'
# Aug 21, 2023 6:53:49 AM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'LiberationSerif-Bold' for 'TimesNewRomanPS-BoldMT'
# Aug 21, 2023 6:53:49 AM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'LiberationSerif' for 'TimesNewRomanPSMT'
# Aug 21, 2023 6:53:49 AM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'LiberationSerif-Bold' for 'TimesNewRomanPS-BoldMT'
# ...

# %%
# !pip install pdfplumber
import pdfplumber
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.5/47.5 kB 1.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 37.6 MB/s eta 0:00:00
# ...

# %%
pdf_path = '/content/ORMC UHC Commercial PA eff 1.1.18.1.pdf'

# Extract tables using pdfplumber
tables = []
with pdfplumber.open(pdf_path) as pdf:
    for page in pdf.pages:
        page_tables = page.extract_tables()
        tables.extend(page_tables)

# Iterate through extracted tables
for table_num, table in enumerate(tables, start=1):
    print(f"Table {table_num}:")
    for row in table:
        print(row)
    print("\n")
# Out:
# Table 1:
# ['All MS-DRGs\nHowever, this service category does not apply where one of these\nservices is billed in connection with Covered Services included in\nany of the other service categories on this Inpatient Service\nCategory Table or Section 3.6________.)', 'MS-DRG', 'Base Rate\n$19,661.00']
#
#
# Table 2:
# ['Obstetrics (Mother Only)* @(see notes * and @ below)\nVaginal Delivery\nMS-DRGs: 767-768, 774-775\nCesarean Section\nMS-DRGs: 765-766', 'Per Case\nPer Case', '$8,306.00\n$10,357.00']
#
#
# Table 3:
# ['Nursery* @ (see notes * and @ below)\n• Normal Newborn: MS-DRG 795\n• Lower Level Neonate: MS-DRGs 789, 792, 794\n• Higher Level Neonate: MS -DRGs 791, 793\n• Severe Level Neonate MS-DRG 790', 'Per Diem\nPer Diem\nPer Diem\nPer Diem', '$1,225.00\n$1,225.00\n$2,818.00\n$2,818.00']
#
#
# Table 4:
# ...
